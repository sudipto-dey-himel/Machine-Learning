# %% [markdown]
# # *Logistic Regression*
# ##### Def: Logistic regression is a supervised machine learning algorithm that accomplishes binary classification takes by predicting the probability of an event or observation.
#
# ![image.png](attachment:image.png)
